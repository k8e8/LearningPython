# %% [markdown]
# https://www.perplexity.ai/search/88657a74-a8c6-49a9-b9cf-0884a64ac45d

# %%
# %pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9712 sha256=7676f48f1098f3abaeb18f6aaa75416a558e01747eb4634d4c8654ec3e38102f
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\8b\f1\7f\5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'wget' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wget'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
#下載中文字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont.ttf'

# %%
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

# %%
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt
t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
#print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)
figure, axes = plt.subplots()
axes.plot(t, y1,marker='*',linestyle='',label="90")
axes.plot(t, y2,marker='s',linestyle='',label="0")
axes.plot(t, y3,marker='^',linestyle='',label="-90")
axes.legend(loc="upper right",bbox_to_anchor=(1.18,1))
axes.set_title("sin()的正弦波")
axes.set_xlabel("圓周率")
axes.set_ylabel("正弦波值")
plt.show()

# %%
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt
t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
#print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)
figure, axes = plt.subplots()
plt.plot(t, y1,marker='*',linestyle='',label="90")
plt.plot(t, y2,marker='s',linestyle='',label="0")
plt.plot(t, y3,marker='^',linestyle='',label="-90")
plt.legend(loc="upper right",bbox_to_anchor=(1.18,1))
plt.set_title("sin()的正弦波")
plt.set_xlabel("圓周率")
plt.set_ylabel("正弦波值")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 19
#      17 plt.plot(t, y3,marker='^',linestyle='',label="-90")
#      18 plt.legend(loc="upper right",bbox_to_anchor=(1.18,1))
# ---> 19 plt.set_title("sin()的正弦波")
#      20 plt.set_xlabel("圓周率")
#      21 plt.set_ylabel("正弦波值")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_title'
